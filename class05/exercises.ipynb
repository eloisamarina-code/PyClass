# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/biopyladies/PyClass/blob/main/class05/exercises.ipynb)

# %% [markdown]
# # Exercício

# %% [markdown]
# 1 - Entre no banco de dados NCBI e baixe a sequência de genoma no formato FASTA da espécie *Serratia marcescens* cepa UENF-22GI. Para utilizar somente o arquivo de interesse, descompacte a pasta baixada.
#
# *  Entre no site:
# *  Digite no campo de busca o Assembly RefSeq: GCF_001716895.1
# *  Clique em Download e selecione somente a **coleção ReqSeq** e o **formato genome sequence FASTA**
# *  Salve o arquivo em uma pasta dentro do seu diretório Downloads
# *  Para descompactar no terminal Linux, utilize o comando **unzip** para pastas agrupadas em **.zip**.

# %% [markdown]
# ![AULA-PYLADIES.png](data:image/png;base64,...)
